# %% [markdown]
# <a href="https://colab.research.google.com/github/yeongminChae/assingment_submit/blob/main/norm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 25.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import koreanize_matplotlib

# %%
# 평균 (mu) 및 표준편차 (sigma) 설정
mu = 12
sigma = 3

# x 값 생성
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# PDF 계산
PDF = norm.pdf(x, mu, sigma)

# PDF 그리기
plt.figure(figsize=(8, 6))
plt.plot(x, PDF, 'r-', lw=2)
plt.title('N(12, 3^2)의 확률밀도함수 (PDF)')
plt.xlabel('X')
plt.ylabel('확률밀도')
plt.grid(True)
plt.show()
